# %%
'''
定义节点和关系的数据结构
'''
Node = {
    'type': 'ent, att, num',
    'cls': 'ent1, ent2, att, num',
    'val': 'string'
}
Edge = {
    'cls': 'cls1, cls2',
    'val': 'string',
    'adv_init': '句首的状语',
    'adv_close': '紧跟谓词的状语',
    'moda': '情态动词',
    'modi_head': '头实体的定语',
    'modi_tail': '尾实体的定语'
}
